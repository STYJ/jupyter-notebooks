# %%
import pandas as pd
import numpy as np
import googlemaps
print("Setup Complete")
# Out:
# Setup Complete

# %%
path = "./mrt-locations-cleaned.csv"
df = pd.read_csv(path)

# gmaps = googlemaps.Client(key='INSERT_API_KEY_HERE')

# for i in range(len(df)):
#     res = gmaps.geocode(df.iat[i,0] + " Singapore")
#     try:
#         lat = res[0]['geometry']['location']['lat']
#         lon = res[0]['geometry']['location']['lng']
#         print(lat, lon)
#         df.iat[i, df.columns.get_loc('Lat')] = lat
#         df.iat[i, df.columns.get_loc('Lon')] = lon
#     except Exception as e:
#         print(e)

# df.to_csv('./mrt-location-cleaned.csv')
# Out:
#      Unnamed: 0 planning_area     station_name station_code  year_of_opening  \
# 0             0    Ang Mo Kio     Yio Chu Kang         NS15             1987
# 1             1    Ang Mo Kio       Ang Mo Kio         NS16             1987
# 2             2    Ang Mo Kio       Ang Mo Kio         CR11             2029
# 3             3         Bedok      Tanah Merah          EW4             1989
# 4             4         Bedok            Bedok          EW5             1989
# ..          ...           ...              ...          ...              ...
# 188         188     Woodlands  Woodlands North          TE1             2020
# 189         189     Woodlands  Woodlands North          RTS             2026
# 190         190     Woodlands  Woodlands South          TE3             2020
# 191         191        Yishun           Yishun         NS13             1988
# 192         192        Yishun           Khatib         NS14             1988
#
# ...
