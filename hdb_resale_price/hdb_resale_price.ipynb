# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

import numpy as np
import pandas as pd
import plotly.express as px
import io
from base64 import b64encode
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output


# Helper functions for cleaning data

def get_year_from_month_column(month):
    return int(month[:month.find('-')])


def add_year_of_sale_column(df):
    df['year'] = df.month.map(get_year_from_month_column)


def get_full_address(df):
    df['full_address'] = df['block'] + ' ' + df['street_name']
    df.drop(columns=['block', 'street_name'], inplace=True)


def add_remaining_lease_column(df):
    df['remaining_lease'] = np.int64(99) - (df.year - df['lease_commence_date'])


def add_age_column(df):
    df['age_as_of_2021'] = 2021 - df['lease_commence_date']


def rename_cells(df):
    df['town'] = df['town'].str.title()
    df['flat_type'] = df['flat_type'].str.title()
    df['full_address'] = df['full_address'].str.title()


# Helper functions for creating figure

def create_option(town):
    return {'label': town, 'value': town}


def create_figure(towns):
    if len(towns) != 0:

        # Create dataframe

        df = hdb_data[hdb_data.town.isin(towns)].groupby(
            ['town', 'floor_area_sqm']
        ).resale_price.mean().reset_index()

        # Clean dataframe

        df['resale_price'] = df['resale_price'].astype('int')
        df['floor_area_sqm'] = df['floor_area_sqm'].astype('int')

        towns = df.town.unique()

        # Create figure

        fig = px.scatter(
            df,
            x='floor_area_sqm',
            y='resale_price',
            color='town',
            labels={
                'floor_area_sqm': 'Size of flat (sqm)',
                'resale_price': 'Average resale price',
                'town': 'Location'
            },
            title='Breakdown of HDB resale transactions in the last 5 years',
            height=800,
            trendline="lowess",
            hover_data={'town': False, 'floor_area_sqm': False}
            )
        fig.update_layout(hovermode='x unified')
        fig.update_traces(hovertemplate='%{y}')
        return fig
    else:
        return {}


###############################################################################

# Specify file paths

path_2015 = "./dataset/jan-2015-to-dec-2016.csv"
path_2017 = "./dataset/jan-2017-onwards.csv"

# Read files

a = pd.read_csv(path_2015)
b = pd.read_csv(path_2017)

datasets = [a, b]

# Run cleaning helper functions

for x in datasets:
    add_year_of_sale_column(x)
    add_remaining_lease_column(x)
    add_age_column(x)
    get_full_address(x)
    rename_cells(x)

# Create full dataset

hdb_data = pd.concat([a, b])

# Initialise buffer for chart

buffer = io.StringIO()

# Create default figure

fig = create_figure(hdb_data.town.unique())

# Write to buffer

fig.write_html(buffer)

html_bytes = buffer.getvalue().encode()
encoded = b64encode(html_bytes).decode()

# Create new app

app = dash.Dash(__name__)
server = app.server
app.title = 'HDB Resale Price Breakdown'

# Render chart

app.layout = html.Div([
    html.Label('Towns'),
    dcc.Dropdown(
        id='towns',
        options=[{'label': t, 'value': t} for t in hdb_data.town.unique()],
        value=hdb_data.town.unique()[:5],
        multi=True),
    dcc.Graph(id='chart', figure=fig),
    html.A(
        html.Button('Download HTML'),
        id='download',
        href='data:text/html;base64,' + encoded,
        download='plotly_graph.html')])


@app.callback(Output('chart', 'figure'), Input('towns', 'value'))
def update_graph(towns):
    return create_figure(towns)

if __name__ == '__main__':
    app.run_server(debug=True, use_reloader=False)
# Out:
# Figure({
#     'data': [{'customdata': array([['Ang Mo Kio', 44],
#                                    ['Ang Mo Kio', 45],
#                                    ['Ang Mo Kio', 60],
#                                    ['Ang Mo Kio', 61],
#                                    ['Ang Mo Kio', 66],
#                                    ['Ang Mo Kio', 67],
#                                    ['Ang Mo Kio', 68],
#                                    ['Ang Mo Kio', 69],
#                                    ['Ang Mo Kio', 70],
#                                    ['Ang Mo Kio', 73],
#                                    ['Ang Mo Kio', 74],
#                                    ['Ang Mo Kio', 75],
#                                    ['Ang Mo Kio', 78],
#                                    ['Ang Mo Kio', 81],
#                                    ['Ang Mo Kio', 82],
#                                    ['Ang Mo Kio', 83],
#                                    ['Ang Mo Kio', 85],
#                                    ['Ang Mo Kio', 87],
#                                    ['Ang Mo Kio', 88],
#                                    ['Ang Mo Kio', 89],
#                                    ['Ang Mo Kio', 90],
#                                    ['Ang Mo Kio', 91],
#                                    ['Ang Mo Kio', 92],
#                                    ['Ang Mo Kio', 93],
#                                    ['Ang Mo Kio', 94],
#                                    ['Ang Mo Kio', 95],
#                                    ['Ang Mo Kio', 96],
#                                    ['Ang Mo Kio', 97],
#                                    ['Ang Mo Kio', 98],
#                                    ['Ang Mo Kio', 99],
#                                    ['Ang Mo Kio', 100],
#                                    ['Ang Mo Kio', 101],
#                                    ['Ang Mo Kio', 102],
#                                    ['Ang Mo Kio', 103],
#                                    ['Ang Mo Kio', 105],
#                                    ['Ang Mo Kio', 106],
#                                    ['Ang Mo Kio', 107],
#                                    ['Ang Mo Kio', 108],
#                                    ['Ang Mo Kio', 109],
#                                    ['Ang Mo Kio', 110],
#                                    ['Ang Mo Kio', 111],
#                                    ['Ang Mo Kio', 112],
#                                    ['Ang Mo Kio', 114],
#                                    ['Ang Mo Kio', 117],
#                                    ['Ang Mo Kio', 118],
#                                    ['Ang Mo Kio', 119],
#                                    ['Ang Mo Kio', 120],
#                                    ['Ang Mo Kio', 121],
#                                    ['Ang Mo Kio', 122],
#                                    ['Ang Mo Kio', 123],
#                                    ['Ang Mo Kio', 124],
#                                    ['Ang Mo Kio', 125],
#                                    ['Ang Mo Kio', 126],
#                                    ['Ang Mo Kio', 127],
#                                    ['Ang Mo Kio', 128],
#                                    ['Ang Mo Kio', 130],
#                                    ['Ang Mo Kio', 132],
#                                    ['Ang Mo Kio', 133],
#                                    ['Ang Mo Kio', 134],
#                                    ['Ang Mo Kio', 135],
#                                    ['Ang Mo Kio', 136],
#                                    ['Ang Mo Kio', 137],
#                                    ['Ang Mo Kio', 138],
#                                    ['Ang Mo Kio', 144],
#                                    ['Ang Mo Kio', 145],
#                                    ['Ang Mo Kio', 146],
#                                    ['Ang Mo Kio', 147],
#                                    ['Ang Mo Kio', 148],
#                                    ['Ang Mo Kio', 149],
#                                    ['Ang Mo Kio', 150],
#                                    ['Ang Mo Kio', 151],
#                                    ['Ang Mo Kio', 152],
#                                    ['Ang Mo Kio', 153],
#                                    ['Ang Mo Kio', 155],
#                                    ['Ang Mo Kio', 156],
#                                    ['Ang Mo Kio', 160],
#                                    ['Ang Mo Kio', 161],
#                                    ['Ang Mo Kio', 162],
#                                    ['Ang Mo Kio', 163],
#                                    ['Ang Mo Kio', 164],
#                                    ['Ang Mo Kio', 174],
#                                    ['Ang Mo Kio', 175],
#                                    ['Ang Mo Kio', 176],
#                                    ['Ang Mo Kio', 178]], dtype=object),
#               'hovertemplate': '%{y}',
#               'legendgroup': 'Ang Mo Kio',
#               'marker': {'color': '#636efa', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Ang Mo Kio',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([ 44,  45,  60,  61,  66,  67,  68,  69,  70,  73,  74,  75,  78,  81,
#                            82,  83,  85,  87,  88,  89,  90,  91,  92,  93,  94,  95,  96,  97,
#                            98,  99, 100, 101, 102, 103, 105, 106, 107, 108, 109, 110, 111, 112,
#                           114, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 130,
#                           132, 133, 134, 135, 136, 137, 138, 144, 145, 146, 147, 148, 149, 150,
#                           151, 152, 153, 155, 156, 160, 161, 162, 163, 164, 174, 175, 176, 178]),
#               'xaxis': 'x',
#               'y': array([226376, 214500, 263625, 266296, 259600, 289624, 287183, 286800, 457981,
#                           327698, 313097, 323363, 395000, 347449, 343074, 362991, 564666, 623376,
#                           448878, 367054, 624092, 470553, 417140, 435649, 606072, 582533, 722070,
#                           451860, 469110, 430420, 458699, 395000, 422765, 440975, 441500, 445461,
#                           460750, 554333, 498666, 730400, 777590, 784014, 390000, 717142, 598504,
#                           618340, 684610, 657756, 680000, 595408, 480000, 562857, 599814, 599062,
#                           639986, 670000, 600600, 660300, 621300, 767550, 616299, 655833, 695209,
#                           805000, 805000, 790750, 805987, 795000, 750688, 655944, 660000, 745000,
#                           813333, 835000, 847600, 770000, 822666, 817666, 812828, 700000, 869000,
#                           780000, 825500, 962500]),
#               'yaxis': 'y'},
#              {'hovertemplate': '%{y}',
#               'legendgroup': 'Ang Mo Kio',
#               'marker': {'color': '#636efa', 'symbol': 'circle'},
#               'mode': 'lines',
#               'name': 'Ang Mo Kio',
#               'showlegend': False,
#               'type': 'scattergl',
#               'x': array([ 44,  45,  60,  61,  66,  67,  68,  69,  70,  73,  74,  75,  78,  81,
#                            82,  83,  85,  87,  88,  89,  90,  91,  92,  93,  94,  95,  96,  97,
#                            98,  99, 100, 101, 102, 103, 105, 106, 107, 108, 109, 110, 111, 112,
#                           114, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 130,
#                           132, 133, 134, 135, 136, 137, 138, 144, 145, 146, 147, 148, 149, 150,
#                           151, 152, 153, 155, 156, 160, 161, 162, 163, 164, 174, 175, 176, 178]),
#               'xaxis': 'x',
#               'y': array([193542.58437587, 198545.46063125, 273958.33748328, 278978.31358767,
#                           303982.69050935, 308959.88483907, 313928.15542393, 318887.60831354,
#                           323838.73872306, 338649.63256099, 343575.10126392, 348497.1308135 ,
#                           363272.62213899, 378173.27140041, 383205.62433505, 388289.3135617 ,
#                           398655.95432879, 409302.8098025 , 414813.00050203, 420312.36933127,
#                           425778.98441586, 431268.32063904, 436781.63005949, 442318.47583011,
#                           447876.48482391, 453450.09202139, 459028.55125682, 464719.27189678,
#                           470381.80735174, 475926.07346732, 481420.32524642, 486965.84234652,
#                           492444.63285357, 497853.40981948, 508461.58386532, 513660.57319394,
#                           518805.88290865, 523901.50946897, 528872.31583749, 533882.96718558,
#                           538905.75351967, 543969.60032517, 553967.1467826 , 569810.57597162,
#                           575564.63527287, 581481.32992643, 587262.69821548, 593698.50195378,
#                           599959.22623768, 606299.64574507, 612604.66436551, 618975.39935399,
#                           625383.95102064, 631803.12893796, 638204.19293614, 650421.13156293,
#                           661684.04593004, 667121.97675792, 672473.09998777, 678149.30881429,
#                           683709.34899202, 689141.66762104, 694439.75642209, 722807.93478567,
#                           727485.97740059, 732180.64106804, 736892.70978012, 741621.06546736,
#                           746363.45516639, 751117.0997321 , 755879.3472118 , 760648.24005807,
#                           765422.4564333 , 774982.01044468, 779764.61104784, 798874.45868776,
#                           803638.3647679 , 808394.14305132, 813140.64092323, 817876.73293406,
#                           864576.35554604, 869177.5411494 , 873766.21819203, 882909.31566491]),
#               'yaxis': 'y'},
#              {'customdata': array([['Bedok', 44],
#                                    ['Bedok', 45],
#                                    ['Bedok', 47],
#                                    ...,
#                                    ['Bedok', 173],
#                                    ['Bedok', 174],
#                                    ['Bedok', 176]], dtype=object),
#               'hovertemplate': '%{y}',
#               'legendgroup': 'Bedok',
#               'marker': {'color': '#EF553B', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Bedok',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([ 44,  45,  47,  59,  60,  61,  62,  63,  64,  65,  66,  67,  68,  69,
#                            70,  71,  73,  74,  75,  76,  79,  80,  81,  82,  83,  84,  85,  86,
#                            87,  88,  89,  90,  91,  92,  93,  94,  95,  96,  97,  98,  99, 100,
#                           101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 114, 115,
#                           116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129,
#                           130, 131, 132, 133, 134, 136, 137, 138, 139, 140, 141, 142, 143, 144,
#                           145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 156, 158, 162, 163,
#                           165, 172, 173, 174, 176]),
#               'xaxis': 'x',
#               'y': array([223320, 226860, 250000, 260475, 273779, 277606, 442733, 284333, 282141,
#                           285440, 386496, 293615, 296588, 399888, 293761, 304333, 326889, 298200,
#                           304581, 311166, 313000, 320833, 340227, 347763, 372392, 362551, 553964,
#                           691500, 665734, 386457, 379857, 379375, 390072, 427277, 450933, 598528,
#                           375166, 421216, 619783, 398968, 387400, 468000, 415045, 429898, 422362,
#                           485309, 534804, 496796, 519272, 475067, 697000, 656732, 450269, 750795,
#                           629700, 591130, 647500, 542724, 615902, 596192, 586977, 501728, 526916,
#                           545890, 585000, 573239, 560597, 577289, 565040, 650000, 779000, 737000,
#                           590815, 594661, 614000, 589700, 632432, 618000, 633176, 642141, 723785,
#                           710031, 687909, 730522, 736803, 770025, 709444, 667500, 683875, 650846,
#                           691941, 789500, 740000, 792428, 680000, 752888, 717962, 717777, 774040,
#                           763000, 753000, 740000, 815000]),
#               'yaxis': 'y'},
#              {'hovertemplate': '%{y}',
#               'legendgroup': 'Bedok',
#               'marker': {'color': '#EF553B', 'symbol': 'circle'},
#               'mode': 'lines',
#               'name': 'Bedok',
#               'showlegend': False,
#               'type': 'scattergl',
#               'x': array([ 44,  45,  47,  59,  60,  61,  62,  63,  64,  65,  66,  67,  68,  69,
#                            70,  71,  73,  74,  75,  76,  79,  80,  81,  82,  83,  84,  85,  86,
#                            87,  88,  89,  90,  91,  92,  93,  94,  95,  96,  97,  98,  99, 100,
#                           101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 114, 115,
#                           116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129,
#                           130, 131, 132, 133, 134, 136, 137, 138, 139, 140, 141, 142, 143, 144,
#                           145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 156, 158, 162, 163,
#                           165, 172, 173, 174, 176]),
#               'xaxis': 'x',
#               'y': array([212520.58310185, 216247.90382527, 223731.69319765, 269488.93363249,
#                           273368.50881638, 277258.39093155, 281158.66680413, 285069.41882779,
#                           288990.6843662 , 292922.51352662, 296865.02126295, 300818.3366478 ,
#                           304782.38451809, 308757.0957389 , 312742.42695766, 316738.15595971,
#                           324760.47186667, 328787.34677985, 332825.29031063, 336875.38576591,
#                           349123.08809113, 353252.57552932, 357417.20391276, 361627.28803851,
#                           365894.52365324, 370229.32065264, 374634.93998199, 379519.76115853,
#                           384465.47768605, 389040.59825485, 394071.51068429, 398692.12492613,
#                           403321.12227729, 407970.44467211, 412666.2471993 , 417453.72866221,
#                           422787.11829045, 428147.16089524, 433535.552311  , 438952.64470972,
#                           444396.07583035, 449860.57421849, 455340.34757017, 460825.0260061 ,
#                           466302.21133443, 471761.09086642, 477191.5942713 , 482585.59282473,
#                           487943.82919691, 493271.88153681, 498577.032648  , 503869.43237209,
#                           509163.36756871, 514474.03446037, 525336.99185492, 530732.51532617,
#                           536175.64248106, 541658.13366914, 547168.48309445, 552697.68745676,
#                           558237.97827349, 563781.61721141, 569130.43766052, 574638.71930929,
#                           579921.57599606, 585356.71056905, 590747.65141424, 595883.18235355,
#                           601151.49184768, 606130.08987387, 611023.36124304, 615843.6804947 ,
#                           620828.00423114, 625736.06738577, 630559.56843831, 639714.7182439 ,
#                           644014.09255409, 648207.56206794, 652322.32887229, 656384.29842422,
#                           660414.27492552, 664427.42378287, 668433.86995415, 672439.99534276,
#                           676449.62631851, 680464.71630411, 684485.89344645, 688512.88624857,
#                           692544.98318261, 696581.39575259, 700621.34694731, 704664.18817739,
#                           708709.23444226, 712755.51792611, 720846.83903694, 728927.69897687,
#                           745023.46148787, 749027.83936306, 757007.86006963, 784590.06953034,
#                           788480.95090024, 792358.73015851, 800076.16717141]),
#               'yaxis': 'y'},
#              {'customdata': array([['Bishan', 63],
#                                    ['Bishan', 64],
#                                    ['Bishan', 65],
#                                    ['Bishan', 67],
#                                    ['Bishan', 68],
#                                    ['Bishan', 70],
#                                    ['Bishan', 73],
#                                    ['Bishan', 76],
#                                    ['Bishan', 83],
#                                    ['Bishan', 84],
#                                    ['Bishan', 85],
#                                    ['Bishan', 86],
#                                    ['Bishan', 87],
#                                    ['Bishan', 88],
#                                    ['Bishan', 89],
#                                    ['Bishan', 90],
#                                    ['Bishan', 91],
#                                    ['Bishan', 92],
#                                    ['Bishan', 93],
#                                    ['Bishan', 94],
#                                    ['Bishan', 95],
#                                    ['Bishan', 97],
#                                    ['Bishan', 99],
#                                    ['Bishan', 100],
#                                    ['Bishan', 101],
#                                    ['Bishan', 102],
#                                    ['Bishan', 103],
#                                    ['Bishan', 104],
#                                    ['Bishan', 105],
#                                    ['Bishan', 106],
#                                    ['Bishan', 107],
#                                    ['Bishan', 108],
#                                    ['Bishan', 109],
#                                    ['Bishan', 110],
#                                    ['Bishan', 111],
#                                    ['Bishan', 112],
#                                    ['Bishan', 113],
#                                    ['Bishan', 114],
#                                    ['Bishan', 115],
#                                    ['Bishan', 116],
#                                    ['Bishan', 117],
#                                    ['Bishan', 118],
#                                    ['Bishan', 119],
#                                    ['Bishan', 120],
#                                    ['Bishan', 121],
#                                    ['Bishan', 122],
#                                    ['Bishan', 123],
#                                    ['Bishan', 125],
#                                    ['Bishan', 126],
#                                    ['Bishan', 127],
#                                    ['Bishan', 128],
#                                    ['Bishan', 130],
#                                    ['Bishan', 131],
#                                    ['Bishan', 132],
#                                    ['Bishan', 133],
#                                    ['Bishan', 134],
#                                    ['Bishan', 135],
#                                    ['Bishan', 136],
#                                    ['Bishan', 137],
#                                    ['Bishan', 138],
#                                    ['Bishan', 139],
#                                    ['Bishan', 141],
#                                    ['Bishan', 142],
#                                    ['Bishan', 143],
#                                    ['Bishan', 144],
#                                    ['Bishan', 145],
#                                    ['Bishan', 146],
#                                    ['Bishan', 147],
#                                    ['Bishan', 148],
#                                    ['Bishan', 149],
#                                    ['Bishan', 150],
#                                    ['Bishan', 151],
#                                    ['Bishan', 152],
#                                    ['Bishan', 153],
#                                    ['Bishan', 154],
#                                    ['Bishan', 155],
#                                    ['Bishan', 156],
#                                    ['Bishan', 158],
#                                    ['Bishan', 160],
#                                    ['Bishan', 162],
#                                    ['Bishan', 163],
#                                    ['Bishan', 165],
#                                    ['Bishan', 169],
#                                    ['Bishan', 172],
#                                    ['Bishan', 174],
#                                    ['Bishan', 175],
#                                    ['Bishan', 182],
#                                    ['Bishan', 186],
#                                    ['Bishan', 187],
#                                    ['Bishan', 190],
#                                    ['Bishan', 199]], dtype=object),
#               'hovertemplate': '%{y}',
#               'legendgroup': 'Bishan',
#               'marker': {'color': '#00cc96', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Bishan',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([ 63,  64,  65,  67,  68,  70,  73,  76,  83,  84,  85,  86,  87,  88,
#                            89,  90,  91,  92,  93,  94,  95,  97,  99, 100, 101, 102, 103, 104,
#                           105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118,
#                           119, 120, 121, 122, 123, 125, 126, 127, 128, 130, 131, 132, 133, 134,
#                           135, 136, 137, 138, 139, 141, 142, 143, 144, 145, 146, 147, 148, 149,
#                           150, 151, 152, 153, 154, 155, 156, 158, 160, 162, 163, 165, 169, 172,
#                           174, 175, 182, 186, 187, 190, 199]),
#               'xaxis': 'x',
#               'y': array([ 377500,  375558,  276333,  396108,  261870,  382148,  395000,  400000,
#                            510166,  478524,  514600,  509333,  460000,  465040,  507782,  544452,
#                            570833,  545923,  444444,  488000,  733972,  562666,  595000,  615211,
#                            519000,  608798,  570781,  567584,  559188,  576445,  537375,  601576,
#                            532454,  550333,  602962,  577072,  599068,  614782,  603077,  623727,
#                            635000,  629000,  658600,  851878,  735335,  672016,  740319,  691916,
#                            814333,  722200,  770200,  704600,  750433,  792666,  766000,  732846,
#                            788500,  686600,  773750,  812500,  777000,  889333,  933750,  876750,
#                            827769,  860000,  884835,  842711,  878928,  872500,  958563,  848500,
#                            806477,  941666,  948296,  867333,  972000, 1012666,  966666,  958000,
#                           1053125,  917500,  954222,  870000,  957500,  990000, 1018000,  958000,
#                            940000,  890000,  900000]),
#               'yaxis': 'y'},
#              {'hovertemplate': '%{y}',
#               'legendgroup': 'Bishan',
#               'marker': {'color': '#00cc96', 'symbol': 'circle'},
#               'mode': 'lines',
#               'name': 'Bishan',
#               'showlegend': False,
#               'type': 'scattergl',
#               'x': array([ 63,  64,  65,  67,  68,  70,  73,  76,  83,  84,  85,  86,  87,  88,
#                            89,  90,  91,  92,  93,  94,  95,  97,  99, 100, 101, 102, 103, 104,
#                           105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118,
#                           119, 120, 121, 122, 123, 125, 126, 127, 128, 130, 131, 132, 133, 134,
#                           135, 136, 137, 138, 139, 141, 142, 143, 144, 145, 146, 147, 148, 149,
#                           150, 151, 152, 153, 154, 155, 156, 158, 160, 162, 163, 165, 169, 172,
#                           174, 175, 182, 186, 187, 190, 199]),
#               'xaxis': 'x',
#               'y': array([ 353538.53210803,  359041.98680516,  364536.38547486,  375495.62943805,
#                            380959.99787581,  391857.44973119,  408129.3610795 ,  424323.97384262,
#                            461956.34639461,  467336.51555917,  472723.29277601,  478118.60205259,
#                            483524.2364941 ,  488941.91690896,  494373.65120721,  499821.79864416,
#                            505288.74740515,  510776.46137594,  516285.98983183,  521817.13251913,
#                            527368.2702431 ,  538506.88536009,  549579.2560707 ,  555009.19446707,
#                            560485.27907245,  565995.87414797,  571545.24476348,  577135.9305539 ,
#                            582768.07022973,  588444.15036143,  593767.32128172,  599515.79233223,
#                            604836.80006099,  610667.24993321,  616003.54019887,  621934.36444672,
#                            627328.980754  ,  632783.28515908,  638356.33446005,  644656.82253358,
#                            651083.38328233,  657636.27194463,  664315.22208612,  671122.15079275,
#                            678046.89005935,  685066.15677692,  692159.4515065 ,  706740.31306988,
#                            713940.23239511,  721199.13937596,  728598.47242328,  743388.34080672,
#                            750816.04812773,  758482.70223852,  765886.37256965,  773238.0738559 ,
#                            780736.97378834,  787937.92224519,  795308.92571762,  802599.99247995,
#                            809782.85689132,  822655.93212866,  828661.0779402 ,  835079.91857798,
#                            840715.08576213,  846199.64476846,  852160.96194423,  857964.00816842,
#                            862942.28045936,  868349.52567226,  872809.91775933,  876984.32233135,
#                            880937.2996533 ,  884739.83771807,  889172.49715711,  892733.33708594,
#                            896193.53701772,  902878.90307894,  909372.64236243,  915776.17745495,
#                            918961.57688131,  925314.78478962,  937963.55631444,  947379.78080043,
#                            953606.64935163,  956701.95470133,  977932.05721516,  989623.03414286,
#                            992484.48386195, 1000910.10376042, 1024784.71382569]),
#               'yaxis': 'y'},
#              {'customdata': array([['Bukit Batok', 59],
#                                    ['Bukit Batok', 60],
#                                    ['Bukit Batok', 64],
#                                    ['Bukit Batok', 65],
#                                    ['Bukit Batok', 66],
#                                    ['Bukit Batok', 67],
#                                    ['Bukit Batok', 68],
#                                    ['Bukit Batok', 69],
#                                    ['Bukit Batok', 70],
#                                    ['Bukit Batok', 71],
#                                    ['Bukit Batok', 72],
#                                    ['Bukit Batok', 73],
#                                    ['Bukit Batok', 74],
#                                    ['Bukit Batok', 75],
#                                    ['Bukit Batok', 77],
#                                    ['Bukit Batok', 80],
#                                    ['Bukit Batok', 82],
#                                    ['Bukit Batok', 83],
#                                    ['Bukit Batok', 84],
#                                    ['Bukit Batok', 85],
#                                    ['Bukit Batok', 86],
#                                    ['Bukit Batok', 88],
#                                    ['Bukit Batok', 89],
#                                    ['Bukit Batok', 90],
#                                    ['Bukit Batok', 91],
#                                    ['Bukit Batok', 92],
#                                    ['Bukit Batok', 93],
#                                    ['Bukit Batok', 94],
#                                    ['Bukit Batok', 95],
#                                    ['Bukit Batok', 96],
#                                    ['Bukit Batok', 97],
#                                    ['Bukit Batok', 98],
#                                    ['Bukit Batok', 99],
#                                    ['Bukit Batok', 100],
#                                    ['Bukit Batok', 101],
#                                    ['Bukit Batok', 102],
#                                    ['Bukit Batok', 103],
#                                    ['Bukit Batok', 104],
#                                    ['Bukit Batok', 105],
#                                    ['Bukit Batok', 106],
#                                    ['Bukit Batok', 107],
#                                    ['Bukit Batok', 108],
#                                    ['Bukit Batok', 109],
#                                    ['Bukit Batok', 110],
#                                    ['Bukit Batok', 111],
#                                    ['Bukit Batok', 112],
#                                    ['Bukit Batok', 113],
#                                    ['Bukit Batok', 115],
#                                    ['Bukit Batok', 116],
#                                    ['Bukit Batok', 117],
#                                    ['Bukit Batok', 118],
#                                    ['Bukit Batok', 119],
#                                    ['Bukit Batok', 120],
#                                    ['Bukit Batok', 121],
#                                    ['Bukit Batok', 122],
#                                    ['Bukit Batok', 123],
#                                    ['Bukit Batok', 125],
#                                    ['Bukit Batok', 126],
#                                    ['Bukit Batok', 127],
#                                    ['Bukit Batok', 128],
#                                    ['Bukit Batok', 129],
#                                    ['Bukit Batok', 130],
#                                    ['Bukit Batok', 131],
#                                    ['Bukit Batok', 132],
#                                    ['Bukit Batok', 133],
#                                    ['Bukit Batok', 134],
#                                    ['Bukit Batok', 136],
#                                    ['Bukit Batok', 138],
#                                    ['Bukit Batok', 139],
#                                    ['Bukit Batok', 140],
#                                    ['Bukit Batok', 141],
#                                    ['Bukit Batok', 142],
#                                    ['Bukit Batok', 143],
#                                    ['Bukit Batok', 144],
#                                    ['Bukit Batok', 145],
#                                    ['Bukit Batok', 146],
#                                    ['Bukit Batok', 147],
#                                    ['Bukit Batok', 148],
#                                    ['Bukit Batok', 149],
#                                    ['Bukit Batok', 150],
#                                    ['Bukit Batok', 151],
#                                    ['Bukit Batok', 152],
#                                    ['Bukit Batok', 153],
#                                    ['Bukit Batok', 154],
#                                    ['Bukit Batok', 155],
#                                    ['Bukit Batok', 156],
#                                    ['Bukit Batok', 165]], dtype=object),
#               'hovertemplate': '%{y}',
#               'legendgroup': 'Bukit Batok',
#               'marker': {'color': '#ab63fa', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Bukit Batok',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([ 59,  60,  64,  65,  66,  67,  68,  69,  70,  71,  72,  73,  74,  75,
#                            77,  80,  82,  83,  84,  85,  86,  88,  89,  90,  91,  92,  93,  94,
#                            95,  96,  97,  98,  99, 100, 101, 102, 103, 104, 105, 106, 107, 108,
#                           109, 110, 111, 112, 113, 115, 116, 117, 118, 119, 120, 121, 122, 123,
#                           125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 136, 138, 139, 140,
#                           141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154,
#                           155, 156, 165]),
#               'xaxis': 'x',
#               'y': array([257446, 254859, 260107, 261250, 271000, 270703, 269933, 273439, 286285,
#                           272722, 281181, 278264, 274971, 281000, 305000, 293333, 297416, 326375,
#                           324946, 297333, 411771, 357325, 337730, 447204, 369033, 412849, 359335,
#                           348645, 418888, 372783, 377000, 372289, 381412, 425961, 415850, 431547,
#                           386586, 401395, 402983, 389400, 401946, 405574, 390333, 564474, 425736,
#                           411000, 655984, 546299, 477907, 548469, 545700, 589209, 515452, 498593,
#                           455598, 485777, 451500, 455000, 537666, 458750, 535000, 504538, 495000,
#                           562299, 612411, 524055, 463800, 526000, 585033, 639320, 621847, 627236,
#                           587288, 710312, 619565, 587591, 580200, 599282, 626696, 624834, 480000,
#                           576500, 576200, 580666, 661934, 613000, 830285]),
#               'yaxis': 'y'},
#              {'hovertemplate': '%{y}',
#               'legendgroup': 'Bukit Batok',
#               'marker': {'color': '#ab63fa', 'symbol': 'circle'},
#               'mode': 'lines',
#               'name': 'Bukit Batok',
#               'showlegend': False,
#               'type': 'scattergl',
#               'x': array([ 59,  60,  64,  65,  66,  67,  68,  69,  70,  71,  72,  73,  74,  75,
#                            77,  80,  82,  83,  84,  85,  86,  88,  89,  90,  91,  92,  93,  94,
#                            95,  96,  97,  98,  99, 100, 101, 102, 103, 104, 105, 106, 107, 108,
#                           109, 110, 111, 112, 113, 115, 116, 117, 118, 119, 120, 121, 122, 123,
#                           125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 136, 138, 139, 140,
#                           141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154,
#                           155, 156, 165]),
#               'xaxis': 'x',
#               'y': array([237493.61217224, 241220.67522948, 256181.53931999, 259933.01215985,
#                           263688.08605637, 267446.20939684, 271206.73241531, 274968.93328502,
#                           278732.06091199, 282495.33051547, 286257.88861741, 290018.9146274 ,
#                           293777.6379561 , 297533.39785509, 305034.29626579, 316255.81177944,
#                           323716.67658411, 327442.27409938, 331166.11330935, 334889.97115291,
#                           338616.43703822, 346093.86984065, 349856.9603423 , 353648.57912625,
#                           357482.23562774, 361372.72142203, 365443.57559417, 369562.95419553,
#                           373620.09621959, 377750.49779231, 382013.18905594, 386294.42298223,
#                           390579.23251588, 394853.0245907 , 399102.04982448, 403319.90356224,
#                           407484.01899466, 411651.95800516, 415792.13682779, 419901.64258392,
#                           423978.39300194, 428026.75112637, 432057.70444824, 436087.24673965,
#                           440014.28840532, 444044.91137871, 447925.17941661, 456214.98662382,
#                           460500.50453867, 464887.14485477, 469366.24363477, 473926.74528006,
#                           478557.70713462, 483248.49847354, 487984.38393617, 492744.60436384,
#                           502255.13033019, 506980.86235112, 511543.60856566, 515968.3811711 ,
#                           520306.55158007, 524592.68490058, 529039.00946962, 533261.48467111,
#                           537468.09000489, 541664.56619573, 550039.94606518, 558407.21128541,
#                           562592.41656143, 566780.64661434, 570972.67838411, 575168.4807841 ,
#                           579367.31548454, 583567.92387011, 587768.91006311, 591968.82799879,
#                           596166.01709515, 600358.91694134, 604546.22053819, 608726.67880424,
#                           612898.83964551, 617061.10198251, 621212.01308522, 625350.70716002,
#                           629477.01513693, 633591.25188708, 670122.97794685]),
#               'yaxis': 'y'},
#              {'customdata': array([['Bukit Merah', 31],
#                                    ['Bukit Merah', 34],
#                                    ['Bukit Merah', 35],
#                                    ...,
#                                    ['Bukit Merah', 151],
#                                    ['Bukit Merah', 153],
#                                    ['Bukit Merah', 157]], dtype=object),
#               'hovertemplate': '%{y}',
#               'legendgroup': 'Bukit Merah',
#               'marker': {'color': '#FFA15A', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Bukit Merah',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([ 31,  34,  35,  39,  40,  42,  43,  44,  45,  46,  47,  48,  49,  51,
#                            53,  54,  55,  56,  58,  59,  60,  62,  63,  64,  65,  66,  67,  68,
#                            69,  70,  71,  72,  73,  74,  75,  76,  77,  79,  80,  81,  82,  83,
#                            84,  85,  86,  87,  88,  89,  90,  91,  92,  93,  94,  95,  96,  97,
#                            98,  99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111,
#                           112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125,
#                           126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139,
#                           140, 141, 146, 151, 153, 157]),
#               'xaxis': 'x',
#               'y': array([191231, 213944, 217500, 216500, 240000, 231450, 229800, 243467, 234638,
#                           200000, 304296, 254699, 242363, 244250, 256647, 301680, 303000, 286100,
#                           331586, 298399, 433654, 524807, 295772, 349531, 323614, 313800, 352223,
#                           534245, 545031, 333296, 346333, 429928, 364284, 387665, 530199, 363706,
#                           534888, 352500, 434824, 441399, 410524, 410000, 482742, 674062, 523857,
#                           784549, 588113, 763218, 694933, 567129, 667065, 742112, 783145, 790620,
#                           762562, 533444, 515496, 597953, 693980, 657032, 583000, 554278, 534140,
#                           598974, 563416, 625587, 579750, 645666, 830617, 713692, 983736, 932583,
#                           723269, 826032, 680846, 637488, 704167, 695910, 701590, 704260, 687315,
#                           730695, 749521, 756314, 825347, 769243, 823800, 788500, 720000, 853444,
#                           815654, 777571, 643666, 734600, 703733, 787666, 777222, 905666, 870000,
#                           816000, 780000, 765000, 835000, 822333]),
#               'yaxis': 'y'},
#              {'hovertemplate': '%{y}',
#               'legendgroup': 'Bukit Merah',
#               'marker': {'color': '#FFA15A', 'symbol': 'circle'},
#               'mode': 'lines',
#               'name': 'Bukit Merah',
#               'showlegend': False,
#               'type': 'scattergl',
#               'x': array([ 31,  34,  35,  39,  40,  42,  43,  44,  45,  46,  47,  48,  49,  51,
#                            53,  54,  55,  56,  58,  59,  60,  62,  63,  64,  65,  66,  67,  68,
#                            69,  70,  71,  72,  73,  74,  75,  76,  77,  79,  80,  81,  82,  83,
#                            84,  85,  86,  87,  88,  89,  90,  91,  92,  93,  94,  95,  96,  97,
#                            98,  99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111,
#                           112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125,
#                           126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139,
#                           140, 141, 146, 151, 153, 157]),
#               'xaxis': 'x',
#               'y': array([162261.12870121, 179857.2456973 , 185752.13739033, 209481.05187881,
#                           215449.89913716, 227430.06722392, 233440.65736684, 239464.38477027,
#                           245500.84597149, 251549.63083431, 257610.41985525, 263683.07135275,
#                           269767.33466293, 281969.95167142, 294218.07631678, 300359.82313152,
#                           306514.10092529, 312681.69823575, 325061.12574023, 331275.84437019,
#                           337509.65403256, 350043.99644345, 356349.74395137, 362685.28323132,
#                           369054.94292674, 375464.70729377, 381923.06440177, 388441.86682931,
#                           395036.00913615, 401719.66562464, 408671.63524545, 415492.22109607,
#                           422426.53244555, 429298.75742928, 436225.64241355, 443223.28914693,
#                           450046.04612423, 463531.41171824, 470218.7145784 , 476880.84664803,
#                           483519.42869888, 490135.60143832, 496730.18368447, 503302.50175236,
#                           509854.19012928, 516655.75651461, 523196.70577363, 529732.43181729,
#                           536266.41598134, 542803.60892257, 549353.00279647, 556398.29743138,
#                           563015.72414424, 569651.92815147, 576298.98232364, 582944.51048453,
#                           589579.03505449, 596200.79229791, 602804.35502911, 609375.83552029,
#                           615890.63740619, 622311.75071221, 628597.8732578 , 634721.18541565,
#                           640677.12488   , 646468.09074518, 651720.65031361, 656914.85737964,
#                           662388.44625079, 667484.91519875, 672549.87165359, 677798.84569808,
#                           682944.20149008, 687868.44453839, 692722.07318223, 697656.45984187,
#                           702360.40762345, 706966.36013022, 711481.31889037, 715918.90527417,
#                           720294.28216579, 724621.62599469, 728913.17146899, 733178.79821608,
#                           737426.1211015 , 741660.76493859, 745886.56620442, 750106.04508663,
#                           754320.58561994, 758530.83904285, 762737.10079192, 766939.02511487,
#                           771135.77474895, 775326.40006414, 779510.25660317, 783686.95731471,
#                           787856.36489425, 792018.32164455, 796172.5530245 , 800318.30635333,
#                           820876.28860816, 841045.55159903, 848982.2811264 , 864623.5887911 ]),
#               'yaxis': 'y'},
#              {'customdata': array([['Bukit Panjang', 46],
#                                    ['Bukit Panjang', 47],
#                                    ['Bukit Panjang', 64],
#                                    ['Bukit Panjang', 67],
#                                    ['Bukit Panjang', 68],
#                                    ['Bukit Panjang', 70],
#                                    ['Bukit Panjang', 73],
#                                    ['Bukit Panjang', 83],
#                                    ['Bukit Panjang', 84],
#                                    ['Bukit Panjang', 85],
#                                    ['Bukit Panjang', 86],
#                                    ['Bukit Panjang', 88],
#                                    ['Bukit Panjang', 89],
#                                    ['Bukit Panjang', 90],
#                                    ['Bukit Panjang', 91],
#                                    ['Bukit Panjang', 92],
#                                    ['Bukit Panjang', 93],
#                                    ['Bukit Panjang', 94],
#                                    ['Bukit Panjang', 95],
#                                    ['Bukit Panjang', 97],
#                                    ['Bukit Panjang', 99],
#                                    ['Bukit Panjang', 100],
#                                    ['Bukit Panjang', 101],
#                                    ['Bukit Panjang', 102],
#                                    ['Bukit Panjang', 103],
#                                    ['Bukit Panjang', 104],
#                                    ['Bukit Panjang', 105],
#                                    ['Bukit Panjang', 106],
#                                    ['Bukit Panjang', 107],
#                                    ['Bukit Panjang', 108],
#                                    ['Bukit Panjang', 109],
#                                    ['Bukit Panjang', 110],
#                                    ['Bukit Panjang', 111],
#                                    ['Bukit Panjang', 112],
#                                    ['Bukit Panjang', 113],
#                                    ['Bukit Panjang', 114],
#                                    ['Bukit Panjang', 115],
#                                    ['Bukit Panjang', 117],
#                                    ['Bukit Panjang', 118],
#                                    ['Bukit Panjang', 119],
#                                    ['Bukit Panjang', 120],
#                                    ['Bukit Panjang', 121],
#                                    ['Bukit Panjang', 122],
#                                    ['Bukit Panjang', 123],
#                                    ['Bukit Panjang', 124],
#                                    ['Bukit Panjang', 125],
#                                    ['Bukit Panjang', 126],
#                                    ['Bukit Panjang', 127],
#                                    ['Bukit Panjang', 128],
#                                    ['Bukit Panjang', 129],
#                                    ['Bukit Panjang', 130],
#                                    ['Bukit Panjang', 131],
#                                    ['Bukit Panjang', 132],
#                                    ['Bukit Panjang', 133],
#                                    ['Bukit Panjang', 134],
#                                    ['Bukit Panjang', 140],
#                                    ['Bukit Panjang', 141],
#                                    ['Bukit Panjang', 142],
#                                    ['Bukit Panjang', 143],
#                                    ['Bukit Panjang', 144],
#                                    ['Bukit Panjang', 145],
#                                    ['Bukit Panjang', 146],
#                                    ['Bukit Panjang', 147],
#                                    ['Bukit Panjang', 148],
#                                    ['Bukit Panjang', 150],
#                                    ['Bukit Panjang', 151],
#                                    ['Bukit Panjang', 155]], dtype=object),
#               'hovertemplate': '%{y}',
#               'legendgroup': 'Bukit Panjang',
#               'marker': {'color': '#19d3f3', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Bukit Panjang',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([ 46,  47,  64,  67,  68,  70,  73,  83,  84,  85,  86,  88,  89,  90,
#                            91,  92,  93,  94,  95,  97,  99, 100, 101, 102, 103, 104, 105, 106,
#                           107, 108, 109, 110, 111, 112, 113, 114, 115, 117, 118, 119, 120, 121,
#                           122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 140,
#                           141, 142, 143, 144, 145, 146, 147, 148, 150, 151, 155]),
#               'xaxis': 'x',
#               'y': array([226500, 231961, 262511, 319493, 317224, 291250, 283635, 324833, 305880,
#                           340355, 300000, 304333, 290000, 377146, 411139, 421622, 425508, 458747,
#                           356730, 325000, 475016, 395308, 395548, 382705, 354251, 345877, 410750,
#                           350422, 349493, 339009, 344000, 467288, 482395, 518290, 554313, 416666,
#                           388377, 413600, 393648, 415388, 528729, 505514, 442922, 465701, 627690,
#                           515625, 607898, 703000, 451495, 490808, 559047, 629098, 465466, 453500,
#                           463000, 653409, 612324, 629014, 622694, 593093, 595469, 590508, 704000,
#                           730000, 572285, 604432, 613000]),
#               'yaxis': 'y'},
#              {'hovertemplate': '%{y}',
#               'legendgroup': 'Bukit Panjang',
#               'marker': {'color': '#19d3f3', 'symbol': 'circle'},
#               'mode': 'lines',
#               'name': 'Bukit Panjang',
#               'showlegend': False,
#               'type': 'scattergl',
#               'x': array([ 46,  47,  64,  67,  68,  70,  73,  83,  84,  85,  86,  88,  89,  90,
#                            91,  92,  93,  94,  95,  97,  99, 100, 101, 102, 103, 104, 105, 106,
#                           107, 108, 109, 110, 111, 112, 113, 114, 115, 117, 118, 119, 120, 121,
#                           122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 140,
#                           141, 142, 143, 144, 145, 146, 147, 148, 150, 151, 155]),
#               'xaxis': 'x',
#               'y': array([227019.41260608, 229906.24879042, 279242.95438631, 288008.77034461,
# ...
#                           586000, 558500, 639333, 627571, 620800, 613017, 599428, 645166, 618000,
#                           680000, 623296, 653000, 633842, 653854, 625500, 672128, 702852, 698485,
#                           726000, 650000, 682597, 690000, 659600, 760751, 754657]),
#               'yaxis': 'y'},
#              {'hovertemplate': '%{y}',
#               'legendgroup': 'Woodlands',
#               'marker': {'color': '#FFA15A', 'symbol': 'circle'},
#               'mode': 'lines',
#               'name': 'Woodlands',
#               'showlegend': False,
#               'type': 'scattergl',
#               'x': array([ 45,  47,  60,  64,  65,  66,  67,  68,  69,  71,  72,  73,  74,  75,
#                            76,  78,  81,  82,  83,  84,  85,  86,  87,  88,  89,  90,  91,  92,
#                            93,  94,  95,  96,  97,  98,  99, 100, 101, 102, 103, 104, 105, 106,
#                           107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120,
#                           121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 134, 135,
#                           136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149,
#                           150, 151, 152, 153, 154, 155, 156, 158, 160, 161, 162, 163, 164, 166,
#                           168, 169, 170, 172, 173, 174, 175, 176, 177, 179, 182, 183, 184, 186,
#                           187, 189, 192]),
#               'xaxis': 'x',
#               'y': array([195963.39788564, 201473.0110645 , 237675.13408651, 248945.03600831,
#                           251771.39400945, 254601.10333037, 257434.05136683, 260270.00666677,
#                           263108.6169752 , 268792.25867892, 271636.46138926, 274481.74357086,
#                           277327.68567738, 280173.85441439, 283019.90340354, 288710.89349892,
#                           297244.96203463, 300090.04348164, 302936.29977616, 305784.80035084,
#                           308636.95378029, 311494.52663535, 314359.61815974, 317234.7023573 ,
#                           320122.68056501, 323026.82720716, 325950.30752662, 328895.2609925 ,
#                           331861.31973586, 334912.67336936, 337975.30996241, 340981.8996963 ,
#                           344000.59474963, 347035.51379864, 350092.5632927 , 353179.61321833,
#                           356305.47268647, 359485.88535776, 362680.80843591, 365920.54733242,
#                           369159.93322903, 372418.99593712, 375702.34839296, 379015.97496553,
#                           382367.12022181, 385762.31865917, 389207.50322499, 392707.59745881,
#                           396265.42443609, 399882.76049059, 403560.77275275, 407298.00405455,
#                           410701.15637214, 414941.59728351, 418442.59988168, 422397.93560658,
#                           426402.88295418, 430451.74476406, 434540.44869189, 438666.7925466 ,
#                           442829.51810028, 447322.38871258, 451538.75563608, 455786.94490181,
#                           460065.98632452, 464373.16928891, 468924.31286664, 473267.38221783,
#                           482008.54251475, 486397.07520945, 490791.61469462, 495190.20248898,
#                           499594.39796221, 504123.03377178, 508534.51213848, 512962.251299  ,
#                           517409.84146331, 521943.38767665, 526416.93644295, 530908.19206391,
#                           535414.74686913, 539916.74007389, 544425.03630283, 548892.97284014,
#                           553349.00244282, 557801.37294679, 562255.10917228, 566712.78092963,
#                           571175.36928648, 575642.86816941, 580114.86681006, 589069.50170986,
#                           598033.29304608, 602517.05214102, 607001.21554336, 611485.11247631,
#                           615968.0999491 , 624929.21146991, 633881.06966612, 638352.58793279,
#                           642820.76508616, 651745.9182762 , 656202.44969746, 660654.72162183,
#                           665102.65692199, 669546.25085822, 673985.601412  , 682851.88977393,
#                           696120.26306009, 700534.61416188, 704944.60745517, 713751.66325496,
#                           718148.98238803, 726932.47407343, 740084.95031316]),
#               'yaxis': 'y'},
#              {'customdata': array([['Yishun', 40],
#                                    ['Yishun', 47],
#                                    ['Yishun', 48],
#                                    ['Yishun', 60],
#                                    ['Yishun', 64],
#                                    ['Yishun', 65],
#                                    ['Yishun', 66],
#                                    ['Yishun', 67],
#                                    ['Yishun', 68],
#                                    ['Yishun', 69],
#                                    ['Yishun', 70],
#                                    ['Yishun', 71],
#                                    ['Yishun', 72],
#                                    ['Yishun', 73],
#                                    ['Yishun', 74],
#                                    ['Yishun', 77],
#                                    ['Yishun', 78],
#                                    ['Yishun', 79],
#                                    ['Yishun', 80],
#                                    ['Yishun', 81],
#                                    ['Yishun', 82],
#                                    ['Yishun', 83],
#                                    ['Yishun', 84],
#                                    ['Yishun', 85],
#                                    ['Yishun', 86],
#                                    ['Yishun', 87],
#                                    ['Yishun', 88],
#                                    ['Yishun', 89],
#                                    ['Yishun', 90],
#                                    ['Yishun', 91],
#                                    ['Yishun', 92],
#                                    ['Yishun', 93],
#                                    ['Yishun', 94],
#                                    ['Yishun', 95],
#                                    ['Yishun', 96],
#                                    ['Yishun', 97],
#                                    ['Yishun', 98],
#                                    ['Yishun', 99],
#                                    ['Yishun', 100],
#                                    ['Yishun', 101],
#                                    ['Yishun', 102],
#                                    ['Yishun', 103],
#                                    ['Yishun', 104],
#                                    ['Yishun', 105],
#                                    ['Yishun', 106],
#                                    ['Yishun', 107],
#                                    ['Yishun', 108],
#                                    ['Yishun', 109],
#                                    ['Yishun', 110],
#                                    ['Yishun', 111],
#                                    ['Yishun', 112],
#                                    ['Yishun', 113],
#                                    ['Yishun', 117],
#                                    ['Yishun', 120],
#                                    ['Yishun', 121],
#                                    ['Yishun', 122],
#                                    ['Yishun', 123],
#                                    ['Yishun', 124],
#                                    ['Yishun', 125],
#                                    ['Yishun', 126],
#                                    ['Yishun', 127],
#                                    ['Yishun', 128],
#                                    ['Yishun', 129],
#                                    ['Yishun', 130],
#                                    ['Yishun', 131],
#                                    ['Yishun', 132],
#                                    ['Yishun', 133],
#                                    ['Yishun', 134],
#                                    ['Yishun', 135],
#                                    ['Yishun', 136],
#                                    ['Yishun', 139],
#                                    ['Yishun', 141],
#                                    ['Yishun', 142],
#                                    ['Yishun', 145],
#                                    ['Yishun', 146],
#                                    ['Yishun', 147],
#                                    ['Yishun', 148],
#                                    ['Yishun', 150],
#                                    ['Yishun', 151],
#                                    ['Yishun', 152],
#                                    ['Yishun', 153],
#                                    ['Yishun', 154],
#                                    ['Yishun', 159],
#                                    ['Yishun', 161],
#                                    ['Yishun', 162],
#                                    ['Yishun', 163],
#                                    ['Yishun', 164],
#                                    ['Yishun', 165],
#                                    ['Yishun', 169],
#                                    ['Yishun', 171],
#                                    ['Yishun', 179],
#                                    ['Yishun', 181]], dtype=object),
#               'hovertemplate': '%{y}',
#               'legendgroup': 'Yishun',
#               'marker': {'color': '#19d3f3', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Yishun',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([ 40,  47,  48,  60,  64,  65,  66,  67,  68,  69,  70,  71,  72,  73,
#                            74,  77,  78,  79,  80,  81,  82,  83,  84,  85,  86,  87,  88,  89,
#                            90,  91,  92,  93,  94,  95,  96,  97,  98,  99, 100, 101, 102, 103,
#                           104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 117, 120, 121, 122,
#                           123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136,
#                           139, 141, 142, 145, 146, 147, 148, 150, 151, 152, 153, 154, 159, 161,
#                           162, 163, 164, 165, 169, 171, 179, 181]),
#               'xaxis': 'x',
#               'y': array([208827, 228951, 230403, 278769, 261226, 260242, 270000, 290360, 278528,
#                           270000, 272181, 271327, 265964, 284155, 277010, 270078, 277888, 266000,
#                           294000, 293750, 302761, 314470, 311561, 325211, 289333, 336000, 329152,
#                           325716, 321333, 363860, 414183, 372647, 324818, 348166, 383134, 412613,
#                           368340, 376099, 341500, 400000, 363333, 377554, 361697, 362402, 363750,
#                           395859, 365404, 359250, 385000, 464561, 516615, 529565, 569955, 439719,
#                           439430, 447670, 468795, 545000, 450812, 443942, 479783, 520000, 439722,
#                           446125, 439941, 482640, 446493, 462888, 435666, 430000, 452500, 533555,
#                           559859, 577072, 568756, 567500, 561625, 570000, 700000, 586000, 607500,
#                           590972, 693666, 661000, 750000, 673114, 719209, 660000, 670980, 782972,
#                           799481, 770375]),
#               'yaxis': 'y'},
#              {'hovertemplate': '%{y}',
#               'legendgroup': 'Yishun',
#               'marker': {'color': '#19d3f3', 'symbol': 'circle'},
#               'mode': 'lines',
#               'name': 'Yishun',
#               'showlegend': False,
#               'type': 'scattergl',
#               'x': array([ 40,  47,  48,  60,  64,  65,  66,  67,  68,  69,  70,  71,  72,  73,
#                            74,  77,  78,  79,  80,  81,  82,  83,  84,  85,  86,  87,  88,  89,
#                            90,  91,  92,  93,  94,  95,  96,  97,  98,  99, 100, 101, 102, 103,
#                           104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 117, 120, 121, 122,
#                           123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136,
#                           139, 141, 142, 145, 146, 147, 148, 150, 151, 152, 153, 154, 159, 161,
#                           162, 163, 164, 165, 169, 171, 179, 181]),
#               'xaxis': 'x',
#               'y': array([199922.35207067, 217664.05342668, 220224.77326526, 251468.47277393,
#                           262067.54609669, 264727.67584788, 267391.07061893, 270057.31748953,
#                           272725.98689226, 275396.56170833, 278068.50791597, 280741.37532499,
#                           283414.86208231, 286088.9062656 , 288763.80244312, 296803.81855032,
#                           299495.88204136, 302199.989715  , 304921.68111583, 307667.5766848 ,
#                           310444.31239411, 313256.45682933, 316191.08762858, 319067.45459905,
#                           321979.27933551, 324926.26655384, 327985.63805876, 331084.04081003,
#                           334111.4801291 , 337165.85666995, 340255.99315761, 343392.10210699,
#                           346584.6527175 , 349841.26163305, 353253.48673715, 356630.92671155,
#                           360149.00446056, 363701.99209443, 367273.34135768, 370845.1775448 ,
#                           374400.45896671, 377924.08374823, 381342.28483306, 384752.63008922,
#                           388114.29976915, 391426.59529281, 394592.07779162, 397851.02919776,
#                           401096.54748065, 404342.96074904, 407556.40742075, 410794.25089214,
#                           424817.3075149 , 436652.02417301, 441139.93156476, 445167.83555334,
#                           449250.27816139, 453389.91426849, 457593.09279925, 461865.61391533,
#                           466215.87147574, 471211.91878841, 476344.2648554 , 480977.27608737,
#                           485686.50666339, 491049.68836912, 496460.67536421, 501903.42201906,
#                           507364.63371994, 512350.93527243, 528638.45539943, 540047.8964255 ,
#                           545802.81511905, 563186.63437318, 569007.3943219 , 574837.46936176,
#                           580675.76509547, 592375.14900258, 598236.1116845 , 604104.83509164,
#                           609981.61016597, 615866.8128271 , 645434.86852281, 657335.69664237,
#                           663302.63951181, 669280.59787241, 675269.46036519, 681269.03323882,
#                           705368.646584  , 717476.3649803 , 766267.03018204, 778546.0104789 ]),
#               'yaxis': 'y'}],
#     'layout': {'height': 800,
#                'hovermode': 'x unified',
#                'legend': {'title': {'text': 'Location'}, 'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'Breakdown of HDB resale transactions in the last 5 years'},
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'Size of flat (sqm)'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'Average resale price'}}}
# })
# Dash is running on http://127.0.0.1:8050/
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
